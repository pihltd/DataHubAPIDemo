# %%
import requests
import os
import json
import ast
import pandas as pd
from IPython.display import display, Markdown
import pprint

# %% [markdown]
# Need to get:
# - submissionID: Get from graphical interface
# - node type: (basically node name)
# - nodeID: really only available from getSubmission query that returns all the existing data
